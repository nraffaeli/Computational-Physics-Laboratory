# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams.update({
    "font.family": "serif",
    "mathtext.fontset": "dejavuserif",
    "xtick.direction": "in",
    "ytick.direction": "in",
    "xtick.top": True,
    "ytick.right": True,
    "axes.linewidth": 1.5,
})

# %%
C = np.loadtxt("../Correlator.txt")

# %%
plt.figure(figsize=(6, 4))
plt.scatter(C[:, 0], C[:, 1], color="blue" )
plt.xlabel(r"Nsweeps")
plt.ylabel(r"$C(t)$")
plt.legend()
plt.show()
# Out:
# /var/folders/y3/hmkzfhj13553n22ygq7syz5r0000gn/T/ipykernel_34080/2309758174.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
