# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams.update({
    "font.family": "serif",
    "mathtext.fontset": "dejavuserif",
    "xtick.direction": "in",
    "ytick.direction": "in",
    "xtick.top": True,
    "ytick.right": True,
    "axes.linewidth": 1.5,
})

# %%
G = np.loadtxt("../Autocorrelator.txt")

# %%
plt.figure(figsize=(6, 4))
plt.scatter(G[:, 0], G[:, 1], color="blue")
plt.xlabel(r"Nsweeps")
plt.ylabel(r"$\Gamma/\Gamma0$")
plt.yscale("log")
plt.legend()
plt.show()
# Out:
# /var/folders/y3/hmkzfhj13553n22ygq7syz5r0000gn/T/ipykernel_29588/2284790950.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
